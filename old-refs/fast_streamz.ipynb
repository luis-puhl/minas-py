# %%
# %gui asyncio

# %%
import numpy as np
from minas.map_minas_support import *
np.random.seed(300)
classes = list(map(mkClass, range(1000)))
clusters = sampleClusters(classes)
inputStream = loopExamplesIter(classes)
examples = list(zip(range(200), inputStream))

# %%
from dask.distributed import Client
client = Client('tcp://192.168.15.14:8786', processes=False, asynchronous=False)

# %%
def minDist(clusters, item):
    dists = map(lambda cl: (sum((cl.center - item) ** 2) ** (1/2), cl), clusters)
    d, cl = min(dists, key=lambda x: x[0])
    return d, cl
counter = 0
results = []
init = time.time()
for i, example in examples:
    counter += 1
    result = minDist(clusters, example.item)
    results.append(result)
elapsed = time.time() - init
len(results)
print(f'minasOnline testSamples {elapsed} seconds, consumed {counter} items, {int(counter / elapsed)} i/s')
# Out:
# minasOnline testSamples 1.3143126964569092 seconds, consumed 200 items, 152 i/s

# %%
from streamz import Stream
import json

# %%
kafkaConfig = {'bootstrap.servers': 'localhost:9092', 'group.id': 'streamz-minas'}
kafkaSource = Stream.from_kafka(['minas'], kafkaConfig, start=True, asynchronous=True)

result = kafkaSource.sink(print)
result.visualize()

# %%
source = Stream()
source.sliding_window(3).sink(print)
for i in range(10):
    source.emit(i)
# Out:
# (0, 1, 2)
# (1, 2, 3)
# (2, 3, 4)
# (3, 4, 5)
# (4, 5, 6)
# (5, 6, 7)
# (6, 7, 8)
# (7, 8, 9)

# %%
kafkaConfig = {'bootstrap.servers': 'localhost:9092', 'group.id': 'streamz-minas'}
topic = 'streamz-minas'
kafkaSource = Stream.from_kafka([topic], kafkaConfig, start=True)

# result = kafkaSource.sink(print)

# %%
kafkaSource.visualize()

# %%
def exampleMap(di):
    if 'example' in di:
        return Example(**di['example'])
    return di
def minDistMap(example):
    return minDist(clusters, example.item)
def combinedMap(jsonItem):
    di = json.loads(jsonItem)
    example = exampleMap(di)
    timeDiff = time.time_ns() - example.timestamp
    return (minDistMap(example), timeDiff)
results = {}
def asSink(name):
    results[name] = []
    results[name + 'timestamp'] = time.time_ns()
    results[name + 'elapsed'] = time.time_ns()
    def f(val):
        results[name].append(val)
        results[name + 'elapsed'] = time.time_ns() - results[name + 'timestamp']
        print(name, val)
    return f
kafkaSource.map(combinedMap).sink(asSink('raw'))
kafkaSource.scatter(loop=client.loop).map(combinedMap).buffer(5).gather().sink(asSink('dask'))
# Out:
# -------------------------------------------------------------------
# ValueError                        Traceback (most recent call last)
# <ipython-input-10-2d0bd423690c> in <module>
#      21     return f
#      22 kafkaSource.map(combinedMap).sink(asSink('raw'))
# ---> 23 kafkaSource.scatter(loop=client.loop).map(combinedMap).buffer(5).gather().sink(asSink('dask'))
#
# ~/project/minas-py/venv/lib/python3.7/site-packages/streamz/core.py in wrapped(*args, **kwargs)
#     212             @functools.wraps(func)
#     213             def wrapped(*args, **kwargs):
# --> 214                 return func(*args, **kwargs)
#     215             setattr(cls, func.__name__, modifier(wrapped))
#     216             return func
#
# ~/project/minas-py/venv/lib/python3.7/site-packages/streamz/dask.py in __init__(self, *args, **kwargs)
#      41         if 'loop' not in kwargs:
#      42             kwargs['loop'] = default_client().loop
# ---> 43         super(DaskStream, self).__init__(*args, **kwargs)
#      44
#      45
#
# ~/project/minas-py/venv/lib/python3.7/site-packages/streamz/core.py in __init__(self, upstream, upstreams, stream_name, loop, asynchronous, ensure_io_loop)
#     118
#     119         self._set_asynchronous(asynchronous)
# --> 120         self._set_loop(loop)
#     121         if ensure_io_loop and not self.loop:
#     122             self._set_asynchronous(False)
#
# ~/project/minas-py/venv/lib/python3.7/site-packages/streamz/core.py in _set_loop(self, loop)
#     133         self.loop = None
#     134         if loop is not None:
# --> 135             self._inform_loop(loop)
#     136         else:
#     137             for upstream in self.upstreams:
#
# ~/project/minas-py/venv/lib/python3.7/site-packages/streamz/core.py in _inform_loop(self, loop)
#     151             for upstream in self.upstreams:
#     152                 if upstream:
# --> 153                     upstream._inform_loop(loop)
#     154             for downstream in self.downstreams:
#     155                 if downstream:
#
# ~/project/minas-py/venv/lib/python3.7/site-packages/streamz/core.py in _inform_loop(self, loop)
#     146         if self.loop is not None:
#     147             if self.loop is not loop:
# --> 148                 raise ValueError("Two different event loops active")
#     149         else:
#     150             self.loop = loop
#
# ValueError: Two different event loops active

# %%
kprod = confluent_kafka.Producer(kafkaConfig)
print(kprod.list_topics().topics)
init = time.time()
counter = 0
for i, example in examples:
    # value = repr(example)[:-1] + ', item=' + repr(example.item) + ')'
    example.timestamp = time.time_ns()
    value = json.dumps({'example': example.__getstate__()})
    kprod.produce(topic=topic, value=value, key=str(i))
    counter += 1
elapsed = time.time() - init
len(results)
print(f'kafka produce {elapsed} seconds, consumed {counter} items, {int(counter / elapsed)} i/s')

# %%
result = source.pluck([0, 3]).sink(print)
result.visualize()

# %%
result = source.buffer(10).accumulate(lambda acc, x: acc + 1, start=0).sink(print)
result.visualize()

# %%
import confluent_kafka
kcons = confluent_kafka.Consumer({'bootstrap.servers': 'localhost:9092', 'group.id': 'pykafka'})
print(kcons.list_topics().topics)
kcons.subscribe(['test'])
messages = kcons.consume(num_messages=1000000, timeout=1)
for message in messages:
    reprr = [message.offset(), message.headers(), message.key(), message.value(), message.error()]
    print(reprr)

# %%
kprod = confluent_kafka.Producer({'bootstrap.servers': 'localhost:9092'})
print(kprod.list_topics().topics)
for i in range(20):
    kprod.produce(topic='test', value=chr(97 + (i%26))* (i+1), key=str(i))

# %%
import time
from streamz import Stream
from tornado.ioloop import IOLoop

def increment(x):
    """ A blocking increment function

    Simulates a computational function that was not designed to work
    asynchronously
    """
    time.sleep(0.1)
    return x + 1

def write(*args, **kwargs):
    print(*args, **kwargs)

async def f():
    source = Stream(asynchronous=True)
    source.scatter().map(increment).gather().sink(write)

    for x in range(10):
        await source.emit(x)
async def f2():
    source = Stream(asynchronous=True)
    source.map(increment).sink(write)

    for x in range(10):
        await source.emit(x)

# %%
ini = time.time()
await f()
print(time.time() - ini)

# %%
ini = time.time()
await f2()
print(time.time() - ini)
# Out:
# raw ((0.14119995143721822, Cluster(label=539, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.602289305757773, sumDistance=1.602289305757773, rolingVarianceSum=1.602289305757773, stdDev=1.602289305757773)), 89712661)
# raw ((0.3779936860594565, Cluster(label=225, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.1967129735730102, sumDistance=1.1967129735730102, rolingVarianceSum=1.1967129735730102, stdDev=1.1967129735730102)), 109286321)
# raw ((0.8959703781245483, Cluster(label=612, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.5680526815449656, sumDistance=1.5680526815449656, rolingVarianceSum=1.5680526815449656, stdDev=1.5680526815449656)), 121218115)
# raw ((0.21733605208422, Cluster(label=566, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.874550114844861, sumDistance=1.874550114844861, rolingVarianceSum=1.874550114844861, stdDev=1.874550114844861)), 135914976)
# raw ((0.016317533844887894, Cluster(label=565, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=0.6204842653310181, sumDistance=0.6204842653310181, rolingVarianceSum=0.6204842653310181, stdDev=0.6204842653310181)), 150048086)
# raw ((0.8980127373896909, Cluster(label=612, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.5680526815449656, sumDistance=1.5680526815449656, rolingVarianceSum=1.5680526815449656, stdDev=1.5680526815449656)), 162327750)
# raw ((0.3245315452563404, Cluster(label=476, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=0.8583483097508398, sumDistance=0.8583483097508398, rolingVarianceSum=0.8583483097508398, stdDev=0.8583483097508398)), 175869116)
# raw ((0.003844134309989645, Cluster(label=828, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=0.8583300839364594, sumDistance=0.8583300839364594, rolingVarianceSum=0.8583300839364594, stdDev=0.8583300839364594)), 193415563)
# raw ((0.05614976961507371, Cluster(label=375, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=0.5173647586476384, sumDistance=0.5173647586476384, rolingVarianceSum=0.5173647586476384, stdDev=0.5173647586476384)), 205520723)
# raw ((0.014764413291794823, Cluster(label=28, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=0.5522165978493844, sumDistance=0.5522165978493844, rolingVarianceSum=0.5522165978493844, stdDev=0.5522165978493844)), 221911538)
# raw ((0.02088886122050884, Cluster(label=526, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=0.9270259983686087, sumDistance=0.9270259983686087, rolingVarianceSum=0.9270259983686087, stdDev=0.9270259983686087)), 242511743)
# raw ((0.9636311099574565, Cluster(label=692, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=0.7107778145125141, sumDistance=0.7107778145125141, rolingVarianceSum=0.7107778145125141, stdDev=0.7107778145125141)), 261807340)
# raw ((0.09273380526789705, Cluster(label=620, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.8264333258025767, sumDistance=1.8264333258025767, rolingVarianceSum=1.8264333258025767, stdDev=1.8264333258025767)), 279526971)
# raw ((0.0205692734665243, Cluster(label=715, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.256855194296875, sumDistance=1.256855194296875, rolingVarianceSum=1.256855194296875, stdDev=1.256855194296875)), 300166090)
# raw ((1.5117214797728094, Cluster(label=575, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.3123149225512052, sumDistance=1.3123149225512052, rolingVarianceSum=1.3123149225512052, stdDev=1.3123149225512052)), 328516349)
# raw ((0.4761558402052332, Cluster(label=575, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.3123149225512052, sumDistance=1.3123149225512052, rolingVarianceSum=1.3123149225512052, stdDev=1.3123149225512052)), 352338928)
# raw ((0.005374745731670973, Cluster(label=406, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.2678751498936025, sumDistance=1.2678751498936025, rolingVarianceSum=1.2678751498936025, stdDev=1.2678751498936025)), 374038686)
# raw ((0.036284471861079554, Cluster(label=247, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=0.9994292921076391, sumDistance=0.9994292921076391, rolingVarianceSum=0.9994292921076391, stdDev=0.9994292921076391)), 397824049)
# raw ((0.45358710281004927, Cluster(label=938, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=0.49268942146534, sumDistance=0.49268942146534, rolingVarianceSum=0.49268942146534, stdDev=0.49268942146534)), 415967688)
# raw ((0.1477266366277056, Cluster(label=539, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.602289305757773, sumDistance=1.602289305757773, rolingVarianceSum=1.602289305757773, stdDev=1.602289305757773)), 430849789)
# raw ((0.014789705893986, Cluster(label=632, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=0.9785002780553415, sumDistance=0.9785002780553415, rolingVarianceSum=0.9785002780553415, stdDev=0.9785002780553415)), 447712922)
# raw ((0.25718166907236656, Cluster(label=692, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=0.7107778145125141, sumDistance=0.7107778145125141, rolingVarianceSum=0.7107778145125141, stdDev=0.7107778145125141)), 462024592)
# raw ((0.5721383850318221, Cluster(label=689, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.1341674722209927, sumDistance=1.1341674722209927, rolingVarianceSum=1.1341674722209927, stdDev=1.1341674722209927)), 474584678)
# raw ((0.17744023402045642, Cluster(label=287, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.0802221285024651, sumDistance=1.0802221285024651, rolingVarianceSum=1.0802221285024651, stdDev=1.0802221285024651)), 485554168)
# raw ((0.24548311792314872, Cluster(label=287, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.0802221285024651, sumDistance=1.0802221285024651, rolingVarianceSum=1.0802221285024651, stdDev=1.0802221285024651)), 499835848)
# raw ((0.023143887364919378, Cluster(label=687, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=0.9252600176142718, sumDistance=0.9252600176142718, rolingVarianceSum=0.9252600176142718, stdDev=0.9252600176142718)), 510074343)
# raw ((0.2381428961308136, Cluster(label=384, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=0.9159263841322752, sumDistance=0.9159263841322752, rolingVarianceSum=0.9159263841322752, stdDev=0.9159263841322752)), 523310101)
# raw ((0.4762081080151294, Cluster(label=575, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.3123149225512052, sumDistance=1.3123149225512052, rolingVarianceSum=1.3123149225512052, stdDev=1.3123149225512052)), 537584651)
# raw ((0.23951242227631372, Cluster(label=747, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.505909647860629, sumDistance=1.505909647860629, rolingVarianceSum=1.505909647860629, stdDev=1.505909647860629)), 547345967)
# raw ((0.47352171568682405, Cluster(label=692, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=0.7107778145125141, sumDistance=0.7107778145125141, rolingVarianceSum=0.7107778145125141, stdDev=0.7107778145125141)), 557445529)
# raw ((0.4235006436004598, Cluster(label=451, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.1235133693271528, sumDistance=1.1235133693271528, rolingVarianceSum=1.1235133693271528, stdDev=1.1235133693271528)), 572847642)
# raw ((0.07792401536365955, Cluster(label=117, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.6608660327495537, sumDistance=1.6608660327495537, rolingVarianceSum=1.6608660327495537, stdDev=1.6608660327495537)), 587598583)
# raw ((0.028940703987649183, Cluster(label=384, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=0.9159263841322752, sumDistance=0.9159263841322752, rolingVarianceSum=0.9159263841322752, stdDev=0.9159263841322752)), 599483644)
# raw ((0.026562361213629964, Cluster(label=739, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=0.9905659775095573, sumDistance=0.9905659775095573, rolingVarianceSum=0.9905659775095573, stdDev=0.9905659775095573)), 612173956)
# raw ((0.01305553326266771, Cluster(label=42, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.3104911328779338, sumDistance=1.3104911328779338, rolingVarianceSum=1.3104911328779338, stdDev=1.3104911328779338)), 623807932)
# raw ((0.3364660354550449, Cluster(label=88, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.6495132197956721, sumDistance=1.6495132197956721, rolingVarianceSum=1.6495132197956721, stdDev=1.6495132197956721)), 633630050)
# raw ((0.662388560389497, Cluster(label=575, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.3123149225512052, sumDistance=1.3123149225512052, rolingVarianceSum=1.3123149225512052, stdDev=1.3123149225512052)), 643421948)
# raw ((0.02073085665746778, Cluster(label=59, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.226374251239959, sumDistance=1.226374251239959, rolingVarianceSum=1.226374251239959, stdDev=1.226374251239959)), 653704665)
# raw ((0.01895019863137817, Cluster(label=714, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=0.14076707464052407, sumDistance=0.14076707464052407, rolingVarianceSum=0.14076707464052407, stdDev=0.14076707464052407)), 663571126)
# raw ((0.08523391022864185, Cluster(label=715, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.256855194296875, sumDistance=1.256855194296875, rolingVarianceSum=1.256855194296875, stdDev=1.256855194296875)), 673482737)
# raw ((0.5443753051168511, Cluster(label=141, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=0.6834190579524175, sumDistance=0.6834190579524175, rolingVarianceSum=0.6834190579524175, stdDev=0.6834190579524175)), 683703805)
# raw ((0.010333850168231129, Cluster(label=889, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.123542409096295, sumDistance=1.123542409096295, rolingVarianceSum=1.123542409096295, stdDev=1.123542409096295)), 694895497)
# raw ((0.07117384145836639, Cluster(label=566, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.874550114844861, sumDistance=1.874550114844861, rolingVarianceSum=1.874550114844861, stdDev=1.874550114844861)), 705453600)
# raw ((1.2324864729102207, Cluster(label=692, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=0.7107778145125141, sumDistance=0.7107778145125141, rolingVarianceSum=0.7107778145125141, stdDev=0.7107778145125141)), 720314798)
# raw ((0.7416945125692224, Cluster(label=612, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.5680526815449656, sumDistance=1.5680526815449656, rolingVarianceSum=1.5680526815449656, stdDev=1.5680526815449656)), 731930357)
# raw ((0.9407180752958951, Cluster(label=225, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.1967129735730102, sumDistance=1.1967129735730102, rolingVarianceSum=1.1967129735730102, stdDev=1.1967129735730102)), 742727343)
# raw ((0.33292351610043186, Cluster(label=46, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=0.6786047399182544, sumDistance=0.6786047399182544, rolingVarianceSum=0.6786047399182544, stdDev=0.6786047399182544)), 752612762)
# raw ((0.014430584104049645, Cluster(label=352, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.975883477780703, sumDistance=1.975883477780703, rolingVarianceSum=1.975883477780703, stdDev=1.975883477780703)), 763181584)
# raw ((0.03670571078548724, Cluster(label=461, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=0.17522182927779495, sumDistance=0.17522182927779495, rolingVarianceSum=0.17522182927779495, stdDev=0.17522182927779495)), 774117329)
# raw ((0.014088015499518911, Cluster(label=481, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.9017188472973148, sumDistance=1.9017188472973148, rolingVarianceSum=1.9017188472973148, stdDev=1.9017188472973148)), 784125675)
# raw ((0.9053271401904921, Cluster(label=566, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.874550114844861, sumDistance=1.874550114844861, rolingVarianceSum=1.874550114844861, stdDev=1.874550114844861)), 797275434)
# raw ((0.12390682417536203, Cluster(label=620, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.8264333258025767, sumDistance=1.8264333258025767, rolingVarianceSum=1.8264333258025767, stdDev=1.8264333258025767)), 808045196)
# raw ((0.03310022959544505, Cluster(label=141, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=0.6834190579524175, sumDistance=0.6834190579524175, rolingVarianceSum=0.6834190579524175, stdDev=0.6834190579524175)), 817963413)
# raw ((0.0852412212640822, Cluster(label=747, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.505909647860629, sumDistance=1.505909647860629, rolingVarianceSum=1.505909647860629, stdDev=1.505909647860629)), 827879260)
# raw ((0.16472055507401165, Cluster(label=117, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.6608660327495537, sumDistance=1.6608660327495537, rolingVarianceSum=1.6608660327495537, stdDev=1.6608660327495537)), 838038555)
# raw ((0.022787710305405474, Cluster(label=921, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.5264543279620626, sumDistance=1.5264543279620626, rolingVarianceSum=1.5264543279620626, stdDev=1.5264543279620626)), 852540637)
# raw ((0.7871336760725021, Cluster(label=384, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=0.9159263841322752, sumDistance=0.9159263841322752, rolingVarianceSum=0.9159263841322752, stdDev=0.9159263841322752)), 863655149)
# raw ((0.7677744663348534, Cluster(label=375, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=0.5173647586476384, sumDistance=0.5173647586476384, rolingVarianceSum=0.5173647586476384, stdDev=0.5173647586476384)), 873807708)
# raw ((0.11935215813357414, Cluster(label=141, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=0.6834190579524175, sumDistance=0.6834190579524175, rolingVarianceSum=0.6834190579524175, stdDev=0.6834190579524175)), 884609328)
# raw ((1.5886268075159156, Cluster(label=141, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=0.6834190579524175, sumDistance=0.6834190579524175, rolingVarianceSum=0.6834190579524175, stdDev=0.6834190579524175)), 894317219)
# raw ((0.32943082782553096, Cluster(label=403, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=0.8685533331948083, sumDistance=0.8685533331948083, rolingVarianceSum=0.8685533331948083, stdDev=0.8685533331948083)), 905523030)
# raw ((0.11956160447724619, Cluster(label=735, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.0817888289001187, sumDistance=1.0817888289001187, rolingVarianceSum=1.0817888289001187, stdDev=1.0817888289001187)), 917861643)
# raw ((0.01995633704532399, Cluster(label=304, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.2861466827964327, sumDistance=1.2861466827964327, rolingVarianceSum=1.2861466827964327, stdDev=1.2861466827964327)), 928211317)
# raw ((0.017083786169455273, Cluster(label=713, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=0.7506617817862324, sumDistance=0.7506617817862324, rolingVarianceSum=0.7506617817862324, stdDev=0.7506617817862324)), 937626846)
# raw ((0.007035269184099159, Cluster(label=989, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=0.8645746859748964, sumDistance=0.8645746859748964, rolingVarianceSum=0.8645746859748964, stdDev=0.8645746859748964)), 947268240)
# raw ((0.024244088514621728, Cluster(label=44, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=0.5754457701568274, sumDistance=0.5754457701568274, rolingVarianceSum=0.5754457701568274, stdDev=0.5754457701568274)), 956398941)
# raw ((0.00809105319399628, Cluster(label=86, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=0.5907177391288428, sumDistance=0.5907177391288428, rolingVarianceSum=0.5907177391288428, stdDev=0.5907177391288428)), 966155947)
# raw ((0.01769387955374785, Cluster(label=209, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=0.1563673774601808, sumDistance=0.1563673774601808, rolingVarianceSum=0.1563673774601808, stdDev=0.1563673774601808)), 976121172)
# raw ((1.928024930364104, Cluster(label=566, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.874550114844861, sumDistance=1.874550114844861, rolingVarianceSum=1.874550114844861, stdDev=1.874550114844861)), 985776339)
# raw ((0.022179841352747965, Cluster(label=300, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=0.6063236930718598, sumDistance=0.6063236930718598, rolingVarianceSum=0.6063236930718598, stdDev=0.6063236930718598)), 995944406)
# raw ((0.018363291626581773, Cluster(label=589, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=0.6973663405114153, sumDistance=0.6973663405114153, rolingVarianceSum=0.6973663405114153, stdDev=0.6973663405114153)), 1007478155)
# raw ((0.01501933307862571, Cluster(label=495, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.8294962363381062, sumDistance=1.8294962363381062, rolingVarianceSum=1.8294962363381062, stdDev=1.8294962363381062)), 1020087621)
# raw ((0.022963054244349725, Cluster(label=72, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=0.1941031336250989, sumDistance=0.1941031336250989, rolingVarianceSum=0.1941031336250989, stdDev=0.1941031336250989)), 1032306665)
# raw ((1.1590534260972454, Cluster(label=88, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.6495132197956721, sumDistance=1.6495132197956721, rolingVarianceSum=1.6495132197956721, stdDev=1.6495132197956721)), 1042699071)
# raw ((0.4817199803510004, Cluster(label=403, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=0.8685533331948083, sumDistance=0.8685533331948083, rolingVarianceSum=0.8685533331948083, stdDev=0.8685533331948083)), 1052463373)
# raw ((1.0483414175145886, Cluster(label=735, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.0817888289001187, sumDistance=1.0817888289001187, rolingVarianceSum=1.0817888289001187, stdDev=1.0817888289001187)), 1061945976)
# raw ((0.4053490375069022, Cluster(label=300, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=0.6063236930718598, sumDistance=0.6063236930718598, rolingVarianceSum=0.6063236930718598, stdDev=0.6063236930718598)), 1071740614)
# raw ((0.07312679353639688, Cluster(label=384, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=0.9159263841322752, sumDistance=0.9159263841322752, rolingVarianceSum=0.9159263841322752, stdDev=0.9159263841322752)), 1081822188)
# raw ((0.06566711113310736, Cluster(label=814, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=0.7391977697861172, sumDistance=0.7391977697861172, rolingVarianceSum=0.7391977697861172, stdDev=0.7391977697861172)), 1091367464)
# raw ((0.6672855477853531, Cluster(label=476, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=0.8583483097508398, sumDistance=0.8583483097508398, rolingVarianceSum=0.8583483097508398, stdDev=0.8583483097508398)), 1103156740)
# raw ((1.4720870764252252, Cluster(label=692, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=0.7107778145125141, sumDistance=0.7107778145125141, rolingVarianceSum=0.7107778145125141, stdDev=0.7107778145125141)), 1112857837)
# raw ((0.575185805223659, Cluster(label=300, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=0.6063236930718598, sumDistance=0.6063236930718598, rolingVarianceSum=0.6063236930718598, stdDev=0.6063236930718598)), 1122561649)
# raw ((0.00422300610669043, Cluster(label=29, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.0562694315691112, sumDistance=1.0562694315691112, rolingVarianceSum=1.0562694315691112, stdDev=1.0562694315691112)), 1132220822)
# raw ((0.01763820368475491, Cluster(label=541, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.2120390438886612, sumDistance=1.2120390438886612, rolingVarianceSum=1.2120390438886612, stdDev=1.2120390438886612)), 1141907378)
# raw ((0.5522592235088688, Cluster(label=451, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.1235133693271528, sumDistance=1.1235133693271528, rolingVarianceSum=1.1235133693271528, stdDev=1.1235133693271528)), 1151812229)
# raw ((0.8397648617490088, Cluster(label=384, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=0.9159263841322752, sumDistance=0.9159263841322752, rolingVarianceSum=0.9159263841322752, stdDev=0.9159263841322752)), 1162021708)
# raw ((0.563217646201984, Cluster(label=300, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=0.6063236930718598, sumDistance=0.6063236930718598, rolingVarianceSum=0.6063236930718598, stdDev=0.6063236930718598)), 1171915985)
# raw ((0.015731599228089522, Cluster(label=977, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.0165822766940211, sumDistance=1.0165822766940211, rolingVarianceSum=1.0165822766940211, stdDev=1.0165822766940211)), 1183182331)
# raw ((0.9341821817544913, Cluster(label=566, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.874550114844861, sumDistance=1.874550114844861, rolingVarianceSum=1.874550114844861, stdDev=1.874550114844861)), 1192365168)
# raw ((0.11598226005809903, Cluster(label=581, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=0.7398991145474483, sumDistance=0.7398991145474483, rolingVarianceSum=0.7398991145474483, stdDev=0.7398991145474483)), 1202421803)
# raw ((0.6881410233139271, Cluster(label=735, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.0817888289001187, sumDistance=1.0817888289001187, rolingVarianceSum=1.0817888289001187, stdDev=1.0817888289001187)), 1213214836)
# raw ((0.11622079458263081, Cluster(label=620, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.8264333258025767, sumDistance=1.8264333258025767, rolingVarianceSum=1.8264333258025767, stdDev=1.8264333258025767)), 1223458304)
# raw ((0.022151871120074645, Cluster(label=535, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=0.9410018154009281, sumDistance=0.9410018154009281, rolingVarianceSum=0.9410018154009281, stdDev=0.9410018154009281)), 1234517388)
# raw ((0.019559058018056623, Cluster(label=715, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.256855194296875, sumDistance=1.256855194296875, rolingVarianceSum=1.256855194296875, stdDev=1.256855194296875)), 1245907289)
# raw ((1.2022077069387578, Cluster(label=620, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.8264333258025767, sumDistance=1.8264333258025767, rolingVarianceSum=1.8264333258025767, stdDev=1.8264333258025767)), 1257752202)
# raw ((1.1601506797177277, Cluster(label=687, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=0.9252600176142718, sumDistance=0.9252600176142718, rolingVarianceSum=0.9252600176142718, stdDev=0.9252600176142718)), 1270170270)
# raw ((0.016267241382949747, Cluster(label=360, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.2011128262581572, sumDistance=1.2011128262581572, rolingVarianceSum=1.2011128262581572, stdDev=1.2011128262581572)), 1280735161)
# raw ((1.3354818669789172, Cluster(label=225, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.1967129735730102, sumDistance=1.1967129735730102, rolingVarianceSum=1.1967129735730102, stdDev=1.1967129735730102)), 1290463059)
# raw ((0.03401496944748496, Cluster(label=3, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.1900700231113865, sumDistance=1.1900700231113865, rolingVarianceSum=1.1900700231113865, stdDev=1.1900700231113865)), 1299847583)
# raw ((0.11163307356326901, Cluster(label=687, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=0.9252600176142718, sumDistance=0.9252600176142718, rolingVarianceSum=0.9252600176142718, stdDev=0.9252600176142718)), 1309230057)
# raw ((0.009145027758209232, Cluster(label=802, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=0.171117063382758, sumDistance=0.171117063382758, rolingVarianceSum=0.171117063382758, stdDev=0.171117063382758)), 1318916757)
# raw ((0.012337440562682933, Cluster(label=766, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=0.5654628190119031, sumDistance=0.5654628190119031, rolingVarianceSum=0.5654628190119031, stdDev=0.5654628190119031)), 1328075727)
# raw ((0.2167370818128981, Cluster(label=375, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=0.5173647586476384, sumDistance=0.5173647586476384, rolingVarianceSum=0.5173647586476384, stdDev=0.5173647586476384)), 1338681476)
# raw ((0.013906719494122756, Cluster(label=221, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=0.6238667630148395, sumDistance=0.6238667630148395, rolingVarianceSum=0.6238667630148395, stdDev=0.6238667630148395)), 1347972593)
# raw ((0.8111823036639209, Cluster(label=641, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=0.16011192351945425, sumDistance=0.16011192351945425, rolingVarianceSum=0.16011192351945425, stdDev=0.16011192351945425)), 1357983525)
# raw ((0.014233578114431128, Cluster(label=733, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=0.685257519500553, sumDistance=0.685257519500553, rolingVarianceSum=0.685257519500553, stdDev=0.685257519500553)), 1367325201)
# raw ((0.01984565291802349, Cluster(label=154, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=0.9207338391515532, sumDistance=0.9207338391515532, rolingVarianceSum=0.9207338391515532, stdDev=0.9207338391515532)), 1376452796)
# raw ((0.006862837929433298, Cluster(label=665, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.730732601556837, sumDistance=1.730732601556837, rolingVarianceSum=1.730732601556837, stdDev=1.730732601556837)), 1386232695)
# raw ((0.49902906671562186, Cluster(label=566, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.874550114844861, sumDistance=1.874550114844861, rolingVarianceSum=1.874550114844861, stdDev=1.874550114844861)), 1396360488)
# raw ((0.1326894731583897, Cluster(label=249, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.130222481117091, sumDistance=1.130222481117091, rolingVarianceSum=1.130222481117091, stdDev=1.130222481117091)), 1406827224)
# raw ((0.8196394407312285, Cluster(label=692, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=0.7107778145125141, sumDistance=0.7107778145125141, rolingVarianceSum=0.7107778145125141, stdDev=0.7107778145125141)), 1416581360)
# raw ((0.01618392686329585, Cluster(label=793, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.3509053235457642, sumDistance=1.3509053235457642, rolingVarianceSum=1.3509053235457642, stdDev=1.3509053235457642)), 1425736283)
# raw ((0.11487365711040176, Cluster(label=88, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.6495132197956721, sumDistance=1.6495132197956721, rolingVarianceSum=1.6495132197956721, stdDev=1.6495132197956721)), 1436023489)
# raw ((0.8101206444474397, Cluster(label=575, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.3123149225512052, sumDistance=1.3123149225512052, rolingVarianceSum=1.3123149225512052, stdDev=1.3123149225512052)), 1445203273)
# raw ((2.364987809979299, Cluster(label=451, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.1235133693271528, sumDistance=1.1235133693271528, rolingVarianceSum=1.1235133693271528, stdDev=1.1235133693271528)), 1455698769)
# raw ((0.017116450163224547, Cluster(label=396, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.0242177860589803, sumDistance=1.0242177860589803, rolingVarianceSum=1.0242177860589803, stdDev=1.0242177860589803)), 1465552586)
# raw ((0.026817516390828463, Cluster(label=364, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.0496762845073158, sumDistance=1.0496762845073158, rolingVarianceSum=1.0496762845073158, stdDev=1.0496762845073158)), 1475086217)
# raw ((0.0031675952212436597, Cluster(label=146, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.1425988541088867, sumDistance=1.1425988541088867, rolingVarianceSum=1.1425988541088867, stdDev=1.1425988541088867)), 1484149412)
# raw ((0.15456952354356585, Cluster(label=864, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=0.6555051861890538, sumDistance=0.6555051861890538, rolingVarianceSum=0.6555051861890538, stdDev=0.6555051861890538)), 1493416714)
# raw ((0.014446500844718798, Cluster(label=147, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.6823338084829074, sumDistance=1.6823338084829074, rolingVarianceSum=1.6823338084829074, stdDev=1.6823338084829074)), 1502577170)
# raw ((0.005203284415297562, Cluster(label=194, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=0.9311310809828971, sumDistance=0.9311310809828971, rolingVarianceSum=0.9311310809828971, stdDev=0.9311310809828971)), 1511887414)
# raw ((0.014260855428675433, Cluster(label=565, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=0.6204842653310181, sumDistance=0.6204842653310181, rolingVarianceSum=0.6204842653310181, stdDev=0.6204842653310181)), 1521030951)
# raw ((0.029000076510262672, Cluster(label=126, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=0.44929434855486594, sumDistance=0.44929434855486594, rolingVarianceSum=0.44929434855486594, stdDev=0.44929434855486594)), 1530073925)
# raw ((0.3825541839313763, Cluster(label=46, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=0.6786047399182544, sumDistance=0.6786047399182544, rolingVarianceSum=0.6786047399182544, stdDev=0.6786047399182544)), 1539204459)
# raw ((0.1173147395760047, Cluster(label=580, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.875513058238494, sumDistance=1.875513058238494, rolingVarianceSum=1.875513058238494, stdDev=1.875513058238494)), 1549100878)
# raw ((0.010759876867112534, Cluster(label=649, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=0.8308217061967278, sumDistance=0.8308217061967278, rolingVarianceSum=0.8308217061967278, stdDev=0.8308217061967278)), 1557817638)
# raw ((0.41558584789537967, Cluster(label=287, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.0802221285024651, sumDistance=1.0802221285024651, rolingVarianceSum=1.0802221285024651, stdDev=1.0802221285024651)), 1566949458)
# raw ((0.05102225687395269, Cluster(label=225, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.1967129735730102, sumDistance=1.1967129735730102, rolingVarianceSum=1.1967129735730102, stdDev=1.1967129735730102)), 1576016748)
# raw ((0.027464568351581526, Cluster(label=498, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=0.4198489257494, sumDistance=0.4198489257494, rolingVarianceSum=0.4198489257494, stdDev=0.4198489257494)), 1585319855)
# raw ((0.7611442220941678, Cluster(label=689, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.1341674722209927, sumDistance=1.1341674722209927, rolingVarianceSum=1.1341674722209927, stdDev=1.1341674722209927)), 1594376006)
# raw ((0.00816904133943299, Cluster(label=68, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.0771212356667195, sumDistance=1.0771212356667195, rolingVarianceSum=1.0771212356667195, stdDev=1.0771212356667195)), 1604184112)
# raw ((0.024593837623609293, Cluster(label=578, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=0.9606887562368573, sumDistance=0.9606887562368573, rolingVarianceSum=0.9606887562368573, stdDev=0.9606887562368573)), 1613142005)
# raw ((0.6967159641032259, Cluster(label=68, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.0771212356667195, sumDistance=1.0771212356667195, rolingVarianceSum=1.0771212356667195, stdDev=1.0771212356667195)), 1622486040)
# raw ((0.14324120763626846, Cluster(label=692, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=0.7107778145125141, sumDistance=0.7107778145125141, rolingVarianceSum=0.7107778145125141, stdDev=0.7107778145125141)), 1631775349)
# raw ((0.01374903033972613, Cluster(label=973, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.718543016309045, sumDistance=1.718543016309045, rolingVarianceSum=1.718543016309045, stdDev=1.718543016309045)), 1641418112)
# raw ((0.6157723450907016, Cluster(label=299, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=0.9779256795417246, sumDistance=0.9779256795417246, rolingVarianceSum=0.9779256795417246, stdDev=0.9779256795417246)), 1652916304)
# raw ((0.03393298545972234, Cluster(label=210, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.8994764108064097, sumDistance=1.8994764108064097, rolingVarianceSum=1.8994764108064097, stdDev=1.8994764108064097)), 1666704385)
# raw ((0.004043652131308266, Cluster(label=812, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.1083737639595217, sumDistance=1.1083737639595217, rolingVarianceSum=1.1083737639595217, stdDev=1.1083737639595217)), 1678230707)
# raw ((0.2563678943115945, Cluster(label=403, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=0.8685533331948083, sumDistance=0.8685533331948083, rolingVarianceSum=0.8685533331948083, stdDev=0.8685533331948083)), 1690432284)
# raw ((0.3662993501590891, Cluster(label=46, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=0.6786047399182544, sumDistance=0.6786047399182544, rolingVarianceSum=0.6786047399182544, stdDev=0.6786047399182544)), 1705358697)
# raw ((0.24373766303866143, Cluster(label=225, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.1967129735730102, sumDistance=1.1967129735730102, rolingVarianceSum=1.1967129735730102, stdDev=1.1967129735730102)), 1716577764)
# raw ((0.10730732801435511, Cluster(label=141, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=0.6834190579524175, sumDistance=0.6834190579524175, rolingVarianceSum=0.6834190579524175, stdDev=0.6834190579524175)), 1727259466)
# raw ((0.15196189607191507, Cluster(label=241, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.2603333673270947, sumDistance=1.2603333673270947, rolingVarianceSum=1.2603333673270947, stdDev=1.2603333673270947)), 1737828614)
# raw ((0.08503386129168275, Cluster(label=495, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.8294962363381062, sumDistance=1.8294962363381062, rolingVarianceSum=1.8294962363381062, stdDev=1.8294962363381062)), 1748887544)
# raw ((0.03047137873071915, Cluster(label=955, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.847930932898684, sumDistance=1.847930932898684, rolingVarianceSum=1.847930932898684, stdDev=1.847930932898684)), 1759536388)
# raw ((0.00559067433484581, Cluster(label=247, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=0.9994292921076391, sumDistance=0.9994292921076391, rolingVarianceSum=0.9994292921076391, stdDev=0.9994292921076391)), 1779396689)
# raw ((0.8580480744675142, Cluster(label=545, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.6208719444588895, sumDistance=1.6208719444588895, rolingVarianceSum=1.6208719444588895, stdDev=1.6208719444588895)), 1791670272)
# raw ((0.18932741720859617, Cluster(label=692, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=0.7107778145125141, sumDistance=0.7107778145125141, rolingVarianceSum=0.7107778145125141, stdDev=0.7107778145125141)), 1802150868)
# raw ((1.388626168082135, Cluster(label=612, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.5680526815449656, sumDistance=1.5680526815449656, rolingVarianceSum=1.5680526815449656, stdDev=1.5680526815449656)), 1812343684)
# raw ((0.531711460535858, Cluster(label=735, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.0817888289001187, sumDistance=1.0817888289001187, rolingVarianceSum=1.0817888289001187, stdDev=1.0817888289001187)), 1821973855)
# raw ((0.6133029897494732, Cluster(label=451, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.1235133693271528, sumDistance=1.1235133693271528, rolingVarianceSum=1.1235133693271528, stdDev=1.1235133693271528)), 1832167065)
# raw ((0.14273961435912844, Cluster(label=747, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.505909647860629, sumDistance=1.505909647860629, rolingVarianceSum=1.505909647860629, stdDev=1.505909647860629)), 1842653778)
# raw ((0.014366515327782294, Cluster(label=828, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=0.8583300839364594, sumDistance=0.8583300839364594, rolingVarianceSum=0.8583300839364594, stdDev=0.8583300839364594)), 1853063529)
# raw ((1.4738615065568392, Cluster(label=566, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.874550114844861, sumDistance=1.874550114844861, rolingVarianceSum=1.874550114844861, stdDev=1.874550114844861)), 1863402328)
# raw ((0.2550352281808561, Cluster(label=372, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=0.6332705638412665, sumDistance=0.6332705638412665, rolingVarianceSum=0.6332705638412665, stdDev=0.6332705638412665)), 1873031810)
# raw ((0.020548238041458586, Cluster(label=492, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.0356623434066838, sumDistance=1.0356623434066838, rolingVarianceSum=1.0356623434066838, stdDev=1.0356623434066838)), 1885665513)
# raw ((0.3401692809675928, Cluster(label=300, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=0.6063236930718598, sumDistance=0.6063236930718598, rolingVarianceSum=0.6063236930718598, stdDev=0.6063236930718598)), 1898161729)
# raw ((0.01661891498625377, Cluster(label=456, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.162628083317328, sumDistance=1.162628083317328, rolingVarianceSum=1.162628083317328, stdDev=1.162628083317328)), 1910110660)
# raw ((0.008988724228326554, Cluster(label=151, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=0.7602278637423382, sumDistance=0.7602278637423382, rolingVarianceSum=0.7602278637423382, stdDev=0.7602278637423382)), 1920912529)
# raw ((0.013278476088560613, Cluster(label=601, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.463268401174381, sumDistance=1.463268401174381, rolingVarianceSum=1.463268401174381, stdDev=1.463268401174381)), 1932341774)
# raw ((0.036293605721954295, Cluster(label=977, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.0165822766940211, sumDistance=1.0165822766940211, rolingVarianceSum=1.0165822766940211, stdDev=1.0165822766940211)), 1942336603)
# raw ((0.44882089332340436, Cluster(label=735, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.0817888289001187, sumDistance=1.0817888289001187, rolingVarianceSum=1.0817888289001187, stdDev=1.0817888289001187)), 1953212910)
# raw ((0.18154534674106754, Cluster(label=605, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=0.9943088012819644, sumDistance=0.9943088012819644, rolingVarianceSum=0.9943088012819644, stdDev=0.9943088012819644)), 1963779642)
# raw ((0.01891649881178843, Cluster(label=924, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=0.5951606946077697, sumDistance=0.5951606946077697, rolingVarianceSum=0.5951606946077697, stdDev=0.5951606946077697)), 1975896590)
# raw ((1.4429763713565862, Cluster(label=612, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.5680526815449656, sumDistance=1.5680526815449656, rolingVarianceSum=1.5680526815449656, stdDev=1.5680526815449656)), 1987452449)
# raw ((1.3747848182671272, Cluster(label=451, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.1235133693271528, sumDistance=1.1235133693271528, rolingVarianceSum=1.1235133693271528, stdDev=1.1235133693271528)), 1997570288)
# raw ((0.5909474398449761, Cluster(label=375, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=0.5173647586476384, sumDistance=0.5173647586476384, rolingVarianceSum=0.5173647586476384, stdDev=0.5173647586476384)), 2008561164)
# raw ((0.3754215315255462, Cluster(label=384, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=0.9159263841322752, sumDistance=0.9159263841322752, rolingVarianceSum=0.9159263841322752, stdDev=0.9159263841322752)), 2018691981)
# raw ((0.520576071590089, Cluster(label=68, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.0771212356667195, sumDistance=1.0771212356667195, rolingVarianceSum=1.0771212356667195, stdDev=1.0771212356667195)), 2030453358)
# raw ((0.1557245417883519, Cluster(label=872, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.7759464271336944, sumDistance=1.7759464271336944, rolingVarianceSum=1.7759464271336944, stdDev=1.7759464271336944)), 2041805785)
# raw ((0.12506640140450612, Cluster(label=299, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=0.9779256795417246, sumDistance=0.9779256795417246, rolingVarianceSum=0.9779256795417246, stdDev=0.9779256795417246)), 2052638612)
# raw ((0.017940065645690305, Cluster(label=525, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.020091853974948, sumDistance=1.020091853974948, rolingVarianceSum=1.020091853974948, stdDev=1.020091853974948)), 2063460799)
# raw ((1.4895428362799465, Cluster(label=545, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.6208719444588895, sumDistance=1.6208719444588895, rolingVarianceSum=1.6208719444588895, stdDev=1.6208719444588895)), 2073882240)
# raw ((0.527196017548109, Cluster(label=567, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=0.7989124455322855, sumDistance=0.7989124455322855, rolingVarianceSum=0.7989124455322855, stdDev=0.7989124455322855)), 2083413914)
# raw ((0.04348827510612856, Cluster(label=687, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=0.9252600176142718, sumDistance=0.9252600176142718, rolingVarianceSum=0.9252600176142718, stdDev=0.9252600176142718)), 2093521170)
# raw ((1.0341424982451357, Cluster(label=566, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.874550114844861, sumDistance=1.874550114844861, rolingVarianceSum=1.874550114844861, stdDev=1.874550114844861)), 2103204845)
# raw ((0.010939218489349164, Cluster(label=420, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=0.569443942084571, sumDistance=0.569443942084571, rolingVarianceSum=0.569443942084571, stdDev=0.569443942084571)), 2113452639)
# raw ((0.050143866294196246, Cluster(label=872, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.7759464271336944, sumDistance=1.7759464271336944, rolingVarianceSum=1.7759464271336944, stdDev=1.7759464271336944)), 2125999829)
# ...
# raw ((0.10730732801435511, Cluster(label=141, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=0.6834190579524175, sumDistance=0.6834190579524175, rolingVarianceSum=0.6834190579524175, stdDev=0.6834190579524175)), 1751116999)
# raw ((0.15196189607191507, Cluster(label=241, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.2603333673270947, sumDistance=1.2603333673270947, rolingVarianceSum=1.2603333673270947, stdDev=1.2603333673270947)), 1763738945)
# raw ((0.08503386129168275, Cluster(label=495, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.8294962363381062, sumDistance=1.8294962363381062, rolingVarianceSum=1.8294962363381062, stdDev=1.8294962363381062)), 1776653645)
# raw ((0.03047137873071915, Cluster(label=955, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.847930932898684, sumDistance=1.847930932898684, rolingVarianceSum=1.847930932898684, stdDev=1.847930932898684)), 1787225023)
# raw ((0.00559067433484581, Cluster(label=247, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=0.9994292921076391, sumDistance=0.9994292921076391, rolingVarianceSum=0.9994292921076391, stdDev=0.9994292921076391)), 1797238435)
# raw ((0.8580480744675142, Cluster(label=545, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.6208719444588895, sumDistance=1.6208719444588895, rolingVarianceSum=1.6208719444588895, stdDev=1.6208719444588895)), 1811222150)
# raw ((0.18932741720859617, Cluster(label=692, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=0.7107778145125141, sumDistance=0.7107778145125141, rolingVarianceSum=0.7107778145125141, stdDev=0.7107778145125141)), 1822007189)
# raw ((1.388626168082135, Cluster(label=612, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.5680526815449656, sumDistance=1.5680526815449656, rolingVarianceSum=1.5680526815449656, stdDev=1.5680526815449656)), 1835051963)
# raw ((0.531711460535858, Cluster(label=735, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.0817888289001187, sumDistance=1.0817888289001187, rolingVarianceSum=1.0817888289001187, stdDev=1.0817888289001187)), 1850323584)
# raw ((0.6133029897494732, Cluster(label=451, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.1235133693271528, sumDistance=1.1235133693271528, rolingVarianceSum=1.1235133693271528, stdDev=1.1235133693271528)), 1862279716)
# raw ((0.14273961435912844, Cluster(label=747, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.505909647860629, sumDistance=1.505909647860629, rolingVarianceSum=1.505909647860629, stdDev=1.505909647860629)), 1873831214)
# raw ((0.014366515327782294, Cluster(label=828, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=0.8583300839364594, sumDistance=0.8583300839364594, rolingVarianceSum=0.8583300839364594, stdDev=0.8583300839364594)), 1888121772)
# raw ((1.4738615065568392, Cluster(label=566, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.874550114844861, sumDistance=1.874550114844861, rolingVarianceSum=1.874550114844861, stdDev=1.874550114844861)), 1900628381)
# raw ((0.2550352281808561, Cluster(label=372, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=0.6332705638412665, sumDistance=0.6332705638412665, rolingVarianceSum=0.6332705638412665, stdDev=0.6332705638412665)), 1918196036)
# raw ((0.020548238041458586, Cluster(label=492, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.0356623434066838, sumDistance=1.0356623434066838, rolingVarianceSum=1.0356623434066838, stdDev=1.0356623434066838)), 1929502255)
# raw ((0.3401692809675928, Cluster(label=300, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=0.6063236930718598, sumDistance=0.6063236930718598, rolingVarianceSum=0.6063236930718598, stdDev=0.6063236930718598)), 1941078400)
# raw ((0.01661891498625377, Cluster(label=456, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.162628083317328, sumDistance=1.162628083317328, rolingVarianceSum=1.162628083317328, stdDev=1.162628083317328)), 1955201294)
# raw ((0.008988724228326554, Cluster(label=151, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=0.7602278637423382, sumDistance=0.7602278637423382, rolingVarianceSum=0.7602278637423382, stdDev=0.7602278637423382)), 1964823592)
# raw ((0.013278476088560613, Cluster(label=601, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.463268401174381, sumDistance=1.463268401174381, rolingVarianceSum=1.463268401174381, stdDev=1.463268401174381)), 1976858398)
# raw ((0.036293605721954295, Cluster(label=977, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.0165822766940211, sumDistance=1.0165822766940211, rolingVarianceSum=1.0165822766940211, stdDev=1.0165822766940211)), 1993311326)
# raw ((0.44882089332340436, Cluster(label=735, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.0817888289001187, sumDistance=1.0817888289001187, rolingVarianceSum=1.0817888289001187, stdDev=1.0817888289001187)), 2004466731)
# raw ((0.18154534674106754, Cluster(label=605, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=0.9943088012819644, sumDistance=0.9943088012819644, rolingVarianceSum=0.9943088012819644, stdDev=0.9943088012819644)), 2016463950)
# raw ((0.01891649881178843, Cluster(label=924, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=0.5951606946077697, sumDistance=0.5951606946077697, rolingVarianceSum=0.5951606946077697, stdDev=0.5951606946077697)), 2026059017)
# raw ((1.4429763713565862, Cluster(label=612, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.5680526815449656, sumDistance=1.5680526815449656, rolingVarianceSum=1.5680526815449656, stdDev=1.5680526815449656)), 2037004179)
# raw ((1.3747848182671272, Cluster(label=451, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.1235133693271528, sumDistance=1.1235133693271528, rolingVarianceSum=1.1235133693271528, stdDev=1.1235133693271528)), 2051100580)
# raw ((0.5909474398449761, Cluster(label=375, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=0.5173647586476384, sumDistance=0.5173647586476384, rolingVarianceSum=0.5173647586476384, stdDev=0.5173647586476384)), 2061187263)
# raw ((0.3754215315255462, Cluster(label=384, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=0.9159263841322752, sumDistance=0.9159263841322752, rolingVarianceSum=0.9159263841322752, stdDev=0.9159263841322752)), 2072892586)
# raw ((0.520576071590089, Cluster(label=68, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.0771212356667195, sumDistance=1.0771212356667195, rolingVarianceSum=1.0771212356667195, stdDev=1.0771212356667195)), 2087119686)
# raw ((0.1557245417883519, Cluster(label=872, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.7759464271336944, sumDistance=1.7759464271336944, rolingVarianceSum=1.7759464271336944, stdDev=1.7759464271336944)), 2100343617)
# raw ((0.12506640140450612, Cluster(label=299, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=0.9779256795417246, sumDistance=0.9779256795417246, rolingVarianceSum=0.9779256795417246, stdDev=0.9779256795417246)), 2113974580)
# raw ((0.017940065645690305, Cluster(label=525, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.020091853974948, sumDistance=1.020091853974948, rolingVarianceSum=1.020091853974948, stdDev=1.020091853974948)), 2125688467)
# raw ((1.4895428362799465, Cluster(label=545, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.6208719444588895, sumDistance=1.6208719444588895, rolingVarianceSum=1.6208719444588895, stdDev=1.6208719444588895)), 2136839347)
# raw ((0.527196017548109, Cluster(label=567, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=0.7989124455322855, sumDistance=0.7989124455322855, rolingVarianceSum=0.7989124455322855, stdDev=0.7989124455322855)), 2147110121)
# raw ((0.04348827510612856, Cluster(label=687, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=0.9252600176142718, sumDistance=0.9252600176142718, rolingVarianceSum=0.9252600176142718, stdDev=0.9252600176142718)), 2157034079)
# raw ((1.0341424982451357, Cluster(label=566, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.874550114844861, sumDistance=1.874550114844861, rolingVarianceSum=1.874550114844861, stdDev=1.874550114844861)), 2167965124)
# raw ((0.010939218489349164, Cluster(label=420, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=0.569443942084571, sumDistance=0.569443942084571, rolingVarianceSum=0.569443942084571, stdDev=0.569443942084571)), 2180552924)
# raw ((0.050143866294196246, Cluster(label=872, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.7759464271336944, sumDistance=1.7759464271336944, rolingVarianceSum=1.7759464271336944, stdDev=1.7759464271336944)), 2190465925)
# raw ((0.12533229910716515, Cluster(label=45, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.4601051059680614, sumDistance=1.4601051059680614, rolingVarianceSum=1.4601051059680614, stdDev=1.4601051059680614)), 2201694186)
# raw ((0.14872839838235802, Cluster(label=747, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.505909647860629, sumDistance=1.505909647860629, rolingVarianceSum=1.505909647860629, stdDev=1.505909647860629)), 2214547845)
# raw ((0.9451676924636351, Cluster(label=735, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.0817888289001187, sumDistance=1.0817888289001187, rolingVarianceSum=1.0817888289001187, stdDev=1.0817888289001187)), 2225047081)
# raw ((0.009389229263578415, Cluster(label=777, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.4936587667486376, sumDistance=1.4936587667486376, rolingVarianceSum=1.4936587667486376, stdDev=1.4936587667486376)), 2234837951)
# raw ((0.008278413302919509, Cluster(label=686, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.1019951674666126, sumDistance=1.1019951674666126, rolingVarianceSum=1.1019951674666126, stdDev=1.1019951674666126)), 2247683714)
# raw ((1.7187502386934144, Cluster(label=68, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.0771212356667195, sumDistance=1.0771212356667195, rolingVarianceSum=1.0771212356667195, stdDev=1.0771212356667195)), 2258646203)
# raw ((0.00565521931833883, Cluster(label=92, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=0.8136372079522306, sumDistance=0.8136372079522306, rolingVarianceSum=0.8136372079522306, stdDev=0.8136372079522306)), 2268749938)
# raw ((0.01500495058192483, Cluster(label=52, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.314328896670636, sumDistance=1.314328896670636, rolingVarianceSum=1.314328896670636, stdDev=1.314328896670636)), 2280782166)
# raw ((0.018609375638955462, Cluster(label=414, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.6073047435337176, sumDistance=1.6073047435337176, rolingVarianceSum=1.6073047435337176, stdDev=1.6073047435337176)), 2289925676)
# raw ((0.01774529983224122, Cluster(label=463, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.4091778937828803, sumDistance=1.4091778937828803, rolingVarianceSum=1.4091778937828803, stdDev=1.4091778937828803)), 2301334756)
# raw ((0.020048451328299636, Cluster(label=679, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=0.7729667638443092, sumDistance=0.7729667638443092, rolingVarianceSum=0.7729667638443092, stdDev=0.7729667638443092)), 2314917619)
# raw ((0.0160746369700587, Cluster(label=855, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.5544632928855568, sumDistance=1.5544632928855568, rolingVarianceSum=1.5544632928855568, stdDev=1.5544632928855568)), 2328112966)
# raw ((0.013604709403912165, Cluster(label=349, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=0.7239150487015366, sumDistance=0.7239150487015366, rolingVarianceSum=0.7239150487015366, stdDev=0.7239150487015366)), 2342640346)
# raw ((0.010955615762048608, Cluster(label=291, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=0.655694718918376, sumDistance=0.655694718918376, rolingVarianceSum=0.655694718918376, stdDev=0.655694718918376)), 2356296262)
# raw ((0.02432528917481786, Cluster(label=39, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=0.4830266260613555, sumDistance=0.4830266260613555, rolingVarianceSum=0.4830266260613555, stdDev=0.4830266260613555)), 2366808734)
# raw ((0.18773156243094377, Cluster(label=545, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.6208719444588895, sumDistance=1.6208719444588895, rolingVarianceSum=1.6208719444588895, stdDev=1.6208719444588895)), 2377666170)
# raw ((0.1456858458274974, Cluster(label=115, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.1429188731178899, sumDistance=1.1429188731178899, rolingVarianceSum=1.1429188731178899, stdDev=1.1429188731178899)), 2386528476)
# raw ((0.04021091527000294, Cluster(label=117, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.6608660327495537, sumDistance=1.6608660327495537, rolingVarianceSum=1.6608660327495537, stdDev=1.6608660327495537)), 2398381856)
# raw ((0.11904578247748028, Cluster(label=620, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.8264333258025767, sumDistance=1.8264333258025767, rolingVarianceSum=1.8264333258025767, stdDev=1.8264333258025767)), 2409992486)
# raw ((0.4131571418649962, Cluster(label=68, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=1.0771212356667195, sumDistance=1.0771212356667195, rolingVarianceSum=1.0771212356667195, stdDev=1.0771212356667195)), 2419730554)
# raw ((0.7060261483730329, Cluster(label=774, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=0.9362642482881999, sumDistance=0.9362642482881999, rolingVarianceSum=0.9362642482881999, stdDev=0.9362642482881999)), 2429796682)
# raw ((0.018741842842111424, Cluster(label=232, n=1, latest=0, timestamp=1558713125713136523, lastExapleTMS=0, maxDistance=0.0, meanDistance=0.9869111422767368, sumDistance=0.9869111422767368, rolingVarianceSum=0.9869111422767368, stdDev=0.9869111422767368)), 2439989478)
