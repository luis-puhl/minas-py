# %%
# GOAL: receber cluster[] e item e retornar o cluster mais próximo
import numpy as np
np.random.seed(300)

clusters = [ (i, np.random.rand(3)) for i in range(100) ]

def dist(clusters, item):
    dists = map(lambda cl: (sum((cl[1] - item) ** 2) ** (1/2), cl[0]), clusters)
    d, cl = min(dists, key=lambda x: x[0])
    return d, cl

# %%
# %%timeit
for i in range(100):
    item = np.random.rand(3)
    d, cl = dist(clusters, item)
#     print(item, d, cl)
# Out:
# 55.9 ms ± 899 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
from dask.distributed import Client
client = Client()
# client = await Client(processes=False, asynchronous=True)
client
# Out:
# tornado.application - ERROR - Multiple exceptions in yield list
# Traceback (most recent call last):
#   File "/mnt/c/dev/minas-py/.venv/lib/python3.7/site-packages/tornado/gen.py", line 501, in callback
#     result_list.append(f.result())
#   File "/mnt/c/dev/minas-py/.venv/lib/python3.7/site-packages/tornado/gen.py", line 736, in run
#     yielded = self.gen.throw(*exc_info)  # type: ignore
#   File "/mnt/c/dev/minas-py/.venv/lib/python3.7/site-packages/distributed/deploy/local.py", line 304, in _start_worker
#     **kwargs
#   File "/mnt/c/dev/minas-py/.venv/lib/python3.7/site-packages/tornado/gen.py", line 729, in run
#     value = future.result()
#   File "/home/puhl/anaconda3/lib/python3.7/asyncio/tasks.py", line 603, in _wrap_awaitable
#     return (yield from awaitable.__await__())
#   File "/mnt/c/dev/minas-py/.venv/lib/python3.7/site-packages/tornado/gen.py", line 736, in run
#     yielded = self.gen.throw(*exc_info)  # type: ignore
#   File "/mnt/c/dev/minas-py/.venv/lib/python3.7/site-packages/distributed/nanny.py", line 195, in _start
#     response = yield self.instantiate()
#   File "/mnt/c/dev/minas-py/.venv/lib/python3.7/site-packages/tornado/gen.py", line 729, in run
#     value = future.result()
#   File "/mnt/c/dev/minas-py/.venv/lib/python3.7/site-packages/tornado/gen.py", line 736, in run
#     yielded = self.gen.throw(*exc_info)  # type: ignore
#   File "/mnt/c/dev/minas-py/.venv/lib/python3.7/site-packages/distributed/nanny.py", line 275, in instantiate
#     timedelta(seconds=self.death_timeout), self.process.start()
#   File "/mnt/c/dev/minas-py/.venv/lib/python3.7/site-packages/tornado/gen.py", line 729, in run
#     value = future.result()
#   File "/mnt/c/dev/minas-py/.venv/lib/python3.7/site-packages/tornado/gen.py", line 736, in run
#     yielded = self.gen.throw(*exc_info)  # type: ignore
#   File "/mnt/c/dev/minas-py/.venv/lib/python3.7/site-packages/distributed/nanny.py", line 434, in start
#     yield self.process.start()
#   File "/mnt/c/dev/minas-py/.venv/lib/python3.7/site-packages/tornado/gen.py", line 729, in run
#     value = future.result()
#   File "/mnt/c/dev/minas-py/.venv/lib/python3.7/site-packages/distributed/process.py", line 35, in _call_and_set_future
#     res = func(*args, **kwargs)
#   File "/mnt/c/dev/minas-py/.venv/lib/python3.7/site-packages/distributed/process.py", line 192, in _start
#     process.start()
#   File "/home/puhl/anaconda3/lib/python3.7/multiprocessing/process.py", line 112, in start
#     self._popen = self._Popen(self)
#   File "/home/puhl/anaconda3/lib/python3.7/multiprocessing/context.py", line 291, in _Popen
#     return Popen(process_obj)
#   File "/home/puhl/anaconda3/lib/python3.7/multiprocessing/popen_forkserver.py", line 35, in __init__
#     super().__init__(process_obj)
#   File "/home/puhl/anaconda3/lib/python3.7/multiprocessing/popen_fork.py", line 20, in __init__
#     self._launch(process_obj)
#   File "/home/puhl/anaconda3/lib/python3.7/multiprocessing/popen_forkserver.py", line 55, in _launch
#     self.pid = forkserver.read_signed(self.sentinel)
#   File "/home/puhl/anaconda3/lib/python3.7/multiprocessing/forkserver.py", line 312, in read_signed
#     raise EOFError('unexpected EOF')
# EOFError: unexpected EOF
# tornado.application - ERROR - Multiple exceptions in yield list
# Traceback (most recent call last):
#   File "/mnt/c/dev/minas-py/.venv/lib/python3.7/site-packages/tornado/gen.py", line 501, in callback
#     result_list.append(f.result())
#   File "/mnt/c/dev/minas-py/.venv/lib/python3.7/site-packages/tornado/gen.py", line 736, in run
#     yielded = self.gen.throw(*exc_info)  # type: ignore
#   File "/mnt/c/dev/minas-py/.venv/lib/python3.7/site-packages/distributed/deploy/local.py", line 304, in _start_worker
#     **kwargs
#   File "/mnt/c/dev/minas-py/.venv/lib/python3.7/site-packages/tornado/gen.py", line 729, in run
#     value = future.result()
#   File "/home/puhl/anaconda3/lib/python3.7/asyncio/tasks.py", line 603, in _wrap_awaitable
#     return (yield from awaitable.__await__())
#   File "/mnt/c/dev/minas-py/.venv/lib/python3.7/site-packages/tornado/gen.py", line 736, in run
#     yielded = self.gen.throw(*exc_info)  # type: ignore
#   File "/mnt/c/dev/minas-py/.venv/lib/python3.7/site-packages/distributed/nanny.py", line 195, in _start
#     response = yield self.instantiate()
#   File "/mnt/c/dev/minas-py/.venv/lib/python3.7/site-packages/tornado/gen.py", line 729, in run
#     value = future.result()
#   File "/mnt/c/dev/minas-py/.venv/lib/python3.7/site-packages/tornado/gen.py", line 736, in run
#     yielded = self.gen.throw(*exc_info)  # type: ignore
#   File "/mnt/c/dev/minas-py/.venv/lib/python3.7/site-packages/distributed/nanny.py", line 275, in instantiate
#     timedelta(seconds=self.death_timeout), self.process.start()
#   File "/mnt/c/dev/minas-py/.venv/lib/python3.7/site-packages/tornado/gen.py", line 729, in run
#     value = future.result()
#   File "/mnt/c/dev/minas-py/.venv/lib/python3.7/site-packages/tornado/gen.py", line 736, in run
#     yielded = self.gen.throw(*exc_info)  # type: ignore
#   File "/mnt/c/dev/minas-py/.venv/lib/python3.7/site-packages/distributed/nanny.py", line 434, in start
#     yield self.process.start()
#   File "/mnt/c/dev/minas-py/.venv/lib/python3.7/site-packages/tornado/gen.py", line 729, in run
#     value = future.result()
#   File "/mnt/c/dev/minas-py/.venv/lib/python3.7/site-packages/distributed/process.py", line 35, in _call_and_set_future
#     res = func(*args, **kwargs)
#   File "/mnt/c/dev/minas-py/.venv/lib/python3.7/site-packages/distributed/process.py", line 192, in _start
#     process.start()
#   File "/home/puhl/anaconda3/lib/python3.7/multiprocessing/process.py", line 112, in start
#     self._popen = self._Popen(self)
#   File "/home/puhl/anaconda3/lib/python3.7/multiprocessing/context.py", line 291, in _Popen
#     return Popen(process_obj)
#   File "/home/puhl/anaconda3/lib/python3.7/multiprocessing/popen_forkserver.py", line 35, in __init__
#     super().__init__(process_obj)
#   File "/home/puhl/anaconda3/lib/python3.7/multiprocessing/popen_fork.py", line 20, in __init__
#     self._launch(process_obj)
#   File "/home/puhl/anaconda3/lib/python3.7/multiprocessing/popen_forkserver.py", line 55, in _launch
#     self.pid = forkserver.read_signed(self.sentinel)
#   File "/home/puhl/anaconda3/lib/python3.7/multiprocessing/forkserver.py", line 312, in read_signed
#     raise EOFError('unexpected EOF')
# EOFError: unexpected EOF
# tornado.application - ERROR - Multiple exceptions in yield list
# Traceback (most recent call last):
#   File "/mnt/c/dev/minas-py/.venv/lib/python3.7/site-packages/tornado/gen.py", line 501, in callback
#     result_list.append(f.result())
#   File "/mnt/c/dev/minas-py/.venv/lib/python3.7/site-packages/tornado/gen.py", line 736, in run
#     yielded = self.gen.throw(*exc_info)  # type: ignore
#   File "/mnt/c/dev/minas-py/.venv/lib/python3.7/site-packages/distributed/deploy/local.py", line 304, in _start_worker
#     **kwargs
#   File "/mnt/c/dev/minas-py/.venv/lib/python3.7/site-packages/tornado/gen.py", line 729, in run
#     value = future.result()
#   File "/home/puhl/anaconda3/lib/python3.7/asyncio/tasks.py", line 603, in _wrap_awaitable
#     return (yield from awaitable.__await__())
#   File "/mnt/c/dev/minas-py/.venv/lib/python3.7/site-packages/tornado/gen.py", line 736, in run
#     yielded = self.gen.throw(*exc_info)  # type: ignore
#   File "/mnt/c/dev/minas-py/.venv/lib/python3.7/site-packages/distributed/nanny.py", line 195, in _start
#     response = yield self.instantiate()
#   File "/mnt/c/dev/minas-py/.venv/lib/python3.7/site-packages/tornado/gen.py", line 729, in run
#     value = future.result()
#   File "/mnt/c/dev/minas-py/.venv/lib/python3.7/site-packages/tornado/gen.py", line 736, in run
#     yielded = self.gen.throw(*exc_info)  # type: ignore
#   File "/mnt/c/dev/minas-py/.venv/lib/python3.7/site-packages/distributed/nanny.py", line 275, in instantiate
#     timedelta(seconds=self.death_timeout), self.process.start()
#   File "/mnt/c/dev/minas-py/.venv/lib/python3.7/site-packages/tornado/gen.py", line 729, in run
#     value = future.result()
#   File "/mnt/c/dev/minas-py/.venv/lib/python3.7/site-packages/tornado/gen.py", line 736, in run
#     yielded = self.gen.throw(*exc_info)  # type: ignore
#   File "/mnt/c/dev/minas-py/.venv/lib/python3.7/site-packages/distributed/nanny.py", line 434, in start
#     yield self.process.start()
#   File "/mnt/c/dev/minas-py/.venv/lib/python3.7/site-packages/tornado/gen.py", line 729, in run
#     value = future.result()
#   File "/mnt/c/dev/minas-py/.venv/lib/python3.7/site-packages/distributed/process.py", line 35, in _call_and_set_future
#     res = func(*args, **kwargs)
#   File "/mnt/c/dev/minas-py/.venv/lib/python3.7/site-packages/distributed/process.py", line 192, in _start
#     process.start()
#   File "/home/puhl/anaconda3/lib/python3.7/multiprocessing/process.py", line 112, in start
#     self._popen = self._Popen(self)
#   File "/home/puhl/anaconda3/lib/python3.7/multiprocessing/context.py", line 291, in _Popen
#     return Popen(process_obj)
#   File "/home/puhl/anaconda3/lib/python3.7/multiprocessing/popen_forkserver.py", line 35, in __init__
#     super().__init__(process_obj)
#   File "/home/puhl/anaconda3/lib/python3.7/multiprocessing/popen_fork.py", line 20, in __init__
#     self._launch(process_obj)
#   File "/home/puhl/anaconda3/lib/python3.7/multiprocessing/popen_forkserver.py", line 55, in _launch
#     self.pid = forkserver.read_signed(self.sentinel)
#   File "/home/puhl/anaconda3/lib/python3.7/multiprocessing/forkserver.py", line 312, in read_signed
#     raise EOFError('unexpected EOF')
# EOFError: unexpected EOF
# ---------------------------------------------------------------------------
# EOFError                                  Traceback (most recent call last)
# <ipython-input-3-9189931ef0f9> in <module>
#       1 from dask.distributed import Client
# ----> 2 client = Client()
#       3 # client = await Client(processes=False, asynchronous=True)
#       4 client
#
# /mnt/c/dev/minas-py/.venv/lib/python3.7/site-packages/distributed/client.py in __init__(self, address, loop, timeout, set_as_default, scheduler_file, security, asynchronous, name, heartbeat_interval, serializers, deserializers, extensions, direct_to_workers, **kwargs)
#     696             ext(self)
#     697
# --> 698         self.start(timeout=timeout)
#     699
#     700         from distributed.recreate_exceptions import ReplayExceptionClient
#
# /mnt/c/dev/minas-py/.venv/lib/python3.7/site-packages/distributed/client.py in start(self, **kwargs)
#     842             self._started = self._start(**kwargs)
#     843         else:
# --> 844             sync(self.loop, self._start, **kwargs)
#     845
#     846     def __await__(self):
#
# /mnt/c/dev/minas-py/.venv/lib/python3.7/site-packages/distributed/utils.py in sync(loop, func, *args, **kwargs)
#     329             e.wait(10)
#     330     if error[0]:
# --> 331         six.reraise(*error[0])
#     332     else:
#     333         return result[0]
#
# /mnt/c/dev/minas-py/.venv/lib/python3.7/site-packages/six.py in reraise(tp, value, tb)
#     691             if value.__traceback__ is not tb:
#     692                 raise value.with_traceback(tb)
# --> 693             raise value
#     694         finally:
#     695             value = None
#
# /mnt/c/dev/minas-py/.venv/lib/python3.7/site-packages/distributed/utils.py in f()
#     314             if timeout is not None:
#     315                 future = gen.with_timeout(timedelta(seconds=timeout), future)
# --> 316             result[0] = yield future
#     317         except Exception as exc:
#     318             error[0] = sys.exc_info()
#
# /mnt/c/dev/minas-py/.venv/lib/python3.7/site-packages/tornado/gen.py in run(self)
#     727
#     728                     try:
# --> 729                         value = future.result()
#     730                     except Exception:
#     731                         exc_info = sys.exc_info()
#
# /mnt/c/dev/minas-py/.venv/lib/python3.7/site-packages/tornado/gen.py in run(self)
#     734                     if exc_info is not None:
#     735                         try:
# --> 736                             yielded = self.gen.throw(*exc_info)  # type: ignore
#     737                         finally:
#     738                             # Break up a reference to itself
#
# /mnt/c/dev/minas-py/.venv/lib/python3.7/site-packages/distributed/client.py in _start(self, timeout, **kwargs)
#     912                     loop=self.loop, asynchronous=True, **self._startup_kwargs
#     913                 )
# --> 914                 yield self.cluster
#     915             except (OSError, socket.error) as e:
#     916                 if e.errno != errno.EADDRINUSE:
#
# /mnt/c/dev/minas-py/.venv/lib/python3.7/site-packages/tornado/gen.py in run(self)
#     727
#     728                     try:
# --> 729                         value = future.result()
#     730                     except Exception:
#     731                         exc_info = sys.exc_info()
#
# ~/anaconda3/lib/python3.7/asyncio/tasks.py in _wrap_awaitable(awaitable)
#     601     that will later be wrapped in a Task by ensure_future().
#     602     """
# --> 603     return (yield from awaitable.__await__())
#     604
#     605
#
# /mnt/c/dev/minas-py/.venv/lib/python3.7/site-packages/tornado/gen.py in run(self)
#     734                     if exc_info is not None:
#     735                         try:
# --> 736                             yielded = self.gen.throw(*exc_info)  # type: ignore
#     737                         finally:
#     738                             # Break up a reference to itself
#
# /mnt/c/dev/minas-py/.venv/lib/python3.7/site-packages/distributed/deploy/local.py in _start(self, ip, n_workers)
#     282         self.scheduler.start(address)
#     283
# --> 284         yield [self._start_worker(**self.worker_kwargs) for i in range(n_workers)]
#     285
#     286         self.status = "running"
#
# /mnt/c/dev/minas-py/.venv/lib/python3.7/site-packages/tornado/gen.py in run(self)
#     727
#     728                     try:
# --> 729                         value = future.result()
#     730                     except Exception:
#     731                         exc_info = sys.exc_info()
#
# /mnt/c/dev/minas-py/.venv/lib/python3.7/site-packages/tornado/gen.py in callback(fut)
#     499             for f in children_futs:
#     500                 try:
# --> 501                     result_list.append(f.result())
#     502                 except Exception as e:
#     503                     if future.done():
#
# /mnt/c/dev/minas-py/.venv/lib/python3.7/site-packages/tornado/gen.py in run(self)
#     734                     if exc_info is not None:
#     735                         try:
# --> 736                             yielded = self.gen.throw(*exc_info)  # type: ignore
#     737                         finally:
#     738                             # Break up a reference to itself
#
# /mnt/c/dev/minas-py/.venv/lib/python3.7/site-packages/distributed/deploy/local.py in _start_worker(self, death_timeout, **kwargs)
#     302             death_timeout=death_timeout,
#     303             silence_logs=self.silence_logs,
# --> 304             **kwargs
#     305         )
#     306
#
# /mnt/c/dev/minas-py/.venv/lib/python3.7/site-packages/tornado/gen.py in run(self)
#     727
#     728                     try:
# --> 729                         value = future.result()
#     730                     except Exception:
#     731                         exc_info = sys.exc_info()
#
# ~/anaconda3/lib/python3.7/asyncio/tasks.py in _wrap_awaitable(awaitable)
#     601     that will later be wrapped in a Task by ensure_future().
#     602     """
# --> 603     return (yield from awaitable.__await__())
#     604
#     605
#
# /mnt/c/dev/minas-py/.venv/lib/python3.7/site-packages/tornado/gen.py in run(self)
#     734                     if exc_info is not None:
#     735                         try:
# --> 736                             yielded = self.gen.throw(*exc_info)  # type: ignore
#     737                         finally:
#     738                             # Break up a reference to itself
#
# /mnt/c/dev/minas-py/.venv/lib/python3.7/site-packages/distributed/nanny.py in _start(self, addr_or_port)
#     193
#     194         logger.info("        Start Nanny at: %r", self.address)
# --> 195         response = yield self.instantiate()
#     196         if response == "running":
#     197             assert self.worker_address
#
# /mnt/c/dev/minas-py/.venv/lib/python3.7/site-packages/tornado/gen.py in run(self)
#     727
#     728                     try:
# --> 729                         value = future.result()
#     730                     except Exception:
#     731                         exc_info = sys.exc_info()
#
# /mnt/c/dev/minas-py/.venv/lib/python3.7/site-packages/tornado/gen.py in run(self)
#     734                     if exc_info is not None:
#     735                         try:
# --> 736                             yielded = self.gen.throw(*exc_info)  # type: ignore
#     737                         finally:
#     738                             # Break up a reference to itself
#
# /mnt/c/dev/minas-py/.venv/lib/python3.7/site-packages/distributed/nanny.py in instantiate(self, comm)
#     273             try:
#     274                 result = yield gen.with_timeout(
# --> 275                     timedelta(seconds=self.death_timeout), self.process.start()
#     276                 )
#     277             except gen.TimeoutError:
#
# /mnt/c/dev/minas-py/.venv/lib/python3.7/site-packages/tornado/gen.py in run(self)
#     727
#     728                     try:
# --> 729                         value = future.result()
#     730                     except Exception:
#     731                         exc_info = sys.exc_info()
#
# /mnt/c/dev/minas-py/.venv/lib/python3.7/site-packages/tornado/gen.py in run(self)
#     734                     if exc_info is not None:
#     735                         try:
# --> 736                             yielded = self.gen.throw(*exc_info)  # type: ignore
#     737                         finally:
#     738                             # Break up a reference to itself
#
# /mnt/c/dev/minas-py/.venv/lib/python3.7/site-packages/distributed/nanny.py in start(self)
#     432         self.stopped = Event()
#     433         self.status = "starting"
# --> 434         yield self.process.start()
#     435         msg = yield self._wait_until_connected(uid)
#     436         if not msg:
#
# /mnt/c/dev/minas-py/.venv/lib/python3.7/site-packages/tornado/gen.py in run(self)
#     727
#     728                     try:
# --> 729                         value = future.result()
#     730                     except Exception:
#     731                         exc_info = sys.exc_info()
#
# /mnt/c/dev/minas-py/.venv/lib/python3.7/site-packages/distributed/process.py in _call_and_set_future(loop, future, func, *args, **kwargs)
#      33 def _call_and_set_future(loop, future, func, *args, **kwargs):
#      34     try:
# ---> 35         res = func(*args, **kwargs)
#      36     except Exception as exc:
#      37         # Tornado futures are not thread-safe, need to
#
# /mnt/c/dev/minas-py/.venv/lib/python3.7/site-packages/distributed/process.py in _start()
#     190
#     191         def _start():
# --> 192             process.start()
#     193
#     194             thread = threading.Thread(
#
# ~/anaconda3/lib/python3.7/multiprocessing/process.py in start(self)
#     110                'daemonic processes are not allowed to have children'
#     111         _cleanup()
# --> 112         self._popen = self._Popen(self)
#     113         self._sentinel = self._popen.sentinel
#     114         # Avoid a refcycle if the target function holds an indirect
#
# ~/anaconda3/lib/python3.7/multiprocessing/context.py in _Popen(process_obj)
#     289         def _Popen(process_obj):
#     290             from .popen_forkserver import Popen
# --> 291             return Popen(process_obj)
#     292
#     293     class ForkContext(BaseContext):
#
# ~/anaconda3/lib/python3.7/multiprocessing/popen_forkserver.py in __init__(self, process_obj)
#      33     def __init__(self, process_obj):
#      34         self._fds = []
# ---> 35         super().__init__(process_obj)
#      36
#      37     def duplicate_for_child(self, fd):
#
# ~/anaconda3/lib/python3.7/multiprocessing/popen_fork.py in __init__(self, process_obj)
#      18         self.returncode = None
#      19         self.finalizer = None
# ---> 20         self._launch(process_obj)
#      21
#      22     def duplicate_for_child(self, fd):
#
# ~/anaconda3/lib/python3.7/multiprocessing/popen_forkserver.py in _launch(self, process_obj)
#      53         with open(w, 'wb', closefd=True) as f:
#      54             f.write(buf.getbuffer())
# ---> 55         self.pid = forkserver.read_signed(self.sentinel)
#      56
#      57     def poll(self, flag=os.WNOHANG):
#
# ~/anaconda3/lib/python3.7/multiprocessing/forkserver.py in read_signed(fd)
#     310         s = os.read(fd, length - len(data))
#     311         if not s:
# --> 312             raise EOFError('unexpected EOF')
#     313         data += s
#     314     return SIGNED_STRUCT.unpack(data)[0]
#
# EOFError: unexpected EOF

# %%
import multiprocessing as mp
import asyncio
import concurrent.futures
import os

def info():
    print('module name:', __name__)
    print('parent process:', os.getppid())
    print('process id:', os.getpid())
    return dict(module=__name__, parent=os.getppid(), pid=os.getpid())
#

async def main():
    print('entering main')
    cpu_bound = lambda : sum(i * i for i in range(10 ** 7))
    loop = asyncio.get_running_loop()
    with concurrent.futures.ProcessPoolExecutor() as pool:
        result = await loop.run_in_executor(pool, cpu_bound)
        print('custom process pool', result)
    print('leaving main')


# loop = asyncio.get_event_loop()
loop = asyncio.get_running_loop()
# loop.run_until_complete(main(loop))
await main()
# Out:
# entering main
# ---------------------------------------------------------------------------
# _RemoteTraceback                          Traceback (most recent call last)
# _RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "C:\dev\Python37\lib\multiprocessing\queues.py", line 236, in _feed
#     obj = _ForkingPickler.dumps(obj)
#   File "C:\dev\Python37\lib\multiprocessing\reduction.py", line 51, in dumps
#     cls(buf, protocol).dump(obj)
# AttributeError: Can't pickle local object 'async-def-wrapper.<locals>.main.<locals>.<lambda>'
# """
#
# The above exception was the direct cause of the following exception:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-38-823f9072435c> in async-def-wrapper()
#
# <ipython-input-38-823f9072435c> in main()
#      19         print('custom process pool', result)
#      20     print('leaving main')
# ---> 21
#      22
#      23 # loop = asyncio.get_event_loop()
#
# C:\dev\Python37\lib\multiprocessing\queues.py in _feed(buffer, notempty, send_bytes, writelock, close, ignore_epipe, onerror, queue_sem)
#     234
#     235                         # serialize the data before acquiring the lock
# --> 236                         obj = _ForkingPickler.dumps(obj)
#     237                         if wacquire is None:
#     238                             send_bytes(obj)
#
# C:\dev\Python37\lib\multiprocessing\reduction.py in dumps(cls, obj, protocol)
#      49     def dumps(cls, obj, protocol=None):
#      50         buf = io.BytesIO()
# ---> 51         cls(buf, protocol).dump(obj)
#      52         return buf.getbuffer()
#      53
#
# AttributeError: Can't pickle local object 'async-def-wrapper.<locals>.main.<locals>.<lambda>'
